# %%
import sympy as sp

from sympy import symbols, simplify, Expr

from sympy import pretty_print

from sympy import factor

from sage.all import *

# %%
run deg3F.ipynb

# %%
# Define variables
#x, y = sp.symbols('x y')
c0, c1, c2,c3, c4, c5, c6, c7, c8, t, s, u = sp.symbols('c0, c1, c2,c3, c4, c5, c6, c7, c8, t, s, u')
#t, s = sp.symbols('t, s')
#a_3, a_2, a_1, a_0, b_3, b_2, b_1, b_0 = symbols('a_3 a_2 a_1 a_0 b_3 b_2 b_1 b_0')

# Define point p in terms of a and b
#q=[1, 0, t, 0, 0, s, 0, 1]     #  L1
#q=[0, s, 0, 1, 1, 0, t, 0]      #  L2
q=[1, 0, 0, -t, 0, 0, 1, 0]      #  L3
#q=[0, t, 0, 1, 1, 0, t, 0]     #  L4
#q=[0, t, 0, -1, 1, 0, -t, 0]     # L_5
#q=[1, 0, 0, -3, 0, -3, 0, 0]      # L_6
#q=[0, 0, 0, 1, 1, 0, 0, 0]     # L_7
 
print(sp.factor(I6(q)))

print(sp.factor(J6(q)))

# Display result
#p=sp.factor(inv(q))
p=inv(q)
print(p)

 
#print(sp.latex(p))
AutGroup(p)

 

#print("Here are the invariants")  
#print(sp.factor(p[0]))
#print(sp.factor(p[1]))
#print(sp.factor(p[2]))
#print(sp.factor(p[3]))
#print(sp.factor(p[4]))
#print(sp.factor(p[5]))

 
 

print("Here is the automorphism group of q") 
 
AutGroup(p)
# Out:
# t
# 3*t*(27*t + 20)
# [-2, 1/6, 3*t/8 + 1/36, -9*t - 2/3, 6*t - 1/9, -27*t**2/4 + 4*t]
# Here is the automorphism group of q
# 'C3'

# %%
p=[-2*u**2, u**2/6, 3*t*u**2/8 + u**3/36, -9*t*u**2 - 2*u**3/3, 6*t*u**3 - u**4/9, -27*t**2*u**3/4 + 4*t*u**4]

# %%
from sage.all import *

# Define the polynomial ring with parameters
R = PolynomialRing(QQ, 't,u,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (1,1,2,2,3,3,4,5)))
t, u, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogeneous parameterization
p_hom = [
    -2 * u**2,
    u**2 / 6,
    (3 * t * u**2) / 8 + u**3 / 36,
    -9 * t * u**2 - (2 * u**3) / 3,
    6 * t * u**3 - u**4 / 9,
    -(27 * t**2 * u**3) / 4 + 4 * t * u**4
]

# Define the ideal
I = R.ideal([x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]])

# Eliminate t and u
I_tu = I.elimination_ideal([t, u])

# Define the weighted projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_tu.gens()])

# Compute the Gröbner basis
G = I_x.groebner_basis()
print("Gröbner basis of I_x:")
for g in G:
    print(g)
    weights = {x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}
    degrees = [sum(weights.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

print("Dimension:", I_x.dimension())

# Verification with p_hom
subs = {x0_rx: p_hom[0], x1_rx: p_hom[1], x2_rx: p_hom[2], x3_rx: p_hom[3], x4_rx: p_hom[4], x5_rx: p_hom[5]}
print("Verification with p_hom:", all(g.subs(subs).is_zero() for g in G))

# Verification with affine p
p = [-2, 1/6, 3*t/8 + 1/36, -9*t - 2/3, 6*t - 1/9, -27*t**2/4 + 4*t]
subs_affine = {x0_rx: p[0], x1_rx: p[1], x2_rx: p[2], x3_rx: p[3], x4_rx: p[4], x5_rx: p[5]}
print("Verification with affine p:", all(g.subs(subs_affine).is_zero() for g in G))
# Out:
# Gröbner basis of I_x:
# ...

# %%
# This is L_2

p=[-2*s**2 - 4*s*t - 2*t**2, 
   s**2/6 - s*t/3 + t**2/6 - 2, 
   -s**3/36 + s**2*t/12 - s*t**2/12 - s*u**2 + t**3/36 + t*u**2, 
   2*s**3/3 + 2*s**2*t/3 - 2*s*t**2/3 - 2*t**3/3, 
   -s**4/9 + 2*s**2*t**2/9 - 4*s**2*u**2/3 - 8*s*t*u**2/3 - t**4/9 - 4*t**2*u**2/3, 
   0*u**5]

# %%
from sage.all import *

# Homogeneous ring
R = PolynomialRing(QQ, 't,u,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (1,1,2,2,3,3,4,5)))
t, u, x0, x1, x2, x3, x4, x5 = R.gens()

p_hom = [-2*u**2, u**2/6, (3*t*u**2)/8 + (u**3)/36, -9*t*u**2 - (2*u**3)/3, 6*t*u**3 - (u**4)/9, -(27*t**2*u**3)/4 + 4*t*u**4]


I = R.ideal([x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]])
I_tu = I.elimination_ideal([t, u])

R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_tu.gens()])
G = I_x.groebner_basis()
print("L_3 Gröbner basis:")
for g in G:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_x.dimension())

# Verification with p_hom
subs = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
print("Verification:", all(R(str(g)).subs(subs).is_zero() for g in G))

# Check original p (u=1)

p = [-2, 1/6, 3*t/8 + 1/36, -9*t - 2/3, 6*t - 1/9, -27*t**2/4 + 4*t]
subs_orig = {x0: p[0], x1: p[1], x2: p[2], x3: p[3], x4: p[4], x5: p[5]}
print("Original p verification:", all(R(str(g)).subs(subs_orig).is_zero() for g in G))
# Out:
# L_3 Gröbner basis:
# ...

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom =[-2*u**2, u**2/6, 3*t*u**2/8 + u**3/36, -9*t*u**2 - 2*u**3/3, 6*t*u**3 - u**4/9, -27*t**2*u**3/4 + 4*t*u**4]

# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis:")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Minimal set: Try degrees 5, 6, 7, 9 (indices 7, 6, 5, 3)
minimal_set = [G[7], G[6], G[5], G[3]]
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Full Gröbner basis:
# ...

# %%
print("Primary decomposition dimensions:", [p.dimension() for p in I_x.associated_primes()])
# Out:
# Primary decomposition dimensions: [3]

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom = [-2*u**2, u**2/6, (3*t*u**2)/8 + (u**3)/36, -9*t*u**2 - (2*u**3)/3, 6*t*u**3 - (u**4)/9, -(27*t**2*u**3)/4 + 4*t*u**4]



# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis:")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Minimal set: Try degrees 5, 6, 7, 8 (indices 7, 6, 5, 4)
minimal_set = [G[7], G[6], G[5], G[4]]  # x5, 6, 7, 8
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Full Gröbner basis:
# ...

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom = [-2*u**2, u**2/6, (3*t*u**2)/8 + (u**3)/36, -9*t*u**2 - (2*u**3)/3, 6*t*u**3 - (u**4)/9, -(27*t**2*u**3)/4 + 4*t*u**4]



# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis:")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Eliminate x1 from I_x
I_x_elim_x1 = I_x.elimination_ideal(x1)
G_elim = I_x_elim_x1.groebner_basis()
print("\nGröbner basis after eliminating x1:")
for g in G_elim:
    print(g)
    degrees = [sum({x0: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(5)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

# Minimal set: Take 4 equations for codimension 4
minimal_set = G_elim[:1]  # Adjust if needed based on output
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(5)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Full Gröbner basis:
# ...

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis:")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Minimal set: Try degrees 5, 6, 7, 9 for codimension 4
minimal_set = [G[7], G[6], G[5], G[3]]  # x5, degree 6, 7, 9
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Full Gröbner basis:
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Minimal generating set:
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# Dimension with minimal set: 3
#
# Verification with parameterization:
# All equations zero: True

# %%
from sage.all import *

# Define the weighted projective space over rationals
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogenized parameterization for L2
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Define the ideal
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

# Dimension and basis
print("Dimension of variety (full basis):", I_x.dimension())
print("Full Gröbner basis:")
for g in G:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

# Select minimal set (aim for codimension 4, dimension 2)
# Try: x5, degree 6, 7, 9 (including x5 explicitly)
minimal_set = [
    G[7],  # x5
    G[6],  # degree 6
    G[5],  # degree 7
    G[3]   # degree 9
]
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Dimension of variety (full basis): 3
# Full Gröbner basis:
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Minimal generating set:
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# Dimension with minimal set: 3
#
# Verification with parameterization:
# All equations zero: True

# %%
from sage.all import *

# Define the weighted projective space over rationals
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogenized parameterization for L2 with exact rationals
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Define the ideal
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

# Dimension and basis
print("Dimension of variety (full basis):", I_x.dimension())
print("Full Gröbner basis:")
for g in G:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

# Select minimal set (codimension 4, dimension 2)
# Take lowest-degree generators up to 4 (assuming ascending degree order)
minimal_set = G[-4:]
I_min = R_x.ideal(minimal_set)
print("\nMinimal generating set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension with minimal set:", I_min.dimension())

# Verification in Sage with exact arithmetic
print("\nVerification with parameterization:")
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set]
is_zero = all(eq.is_zero() for eq in substituted_equations)
print("All equations zero:", is_zero)
if not is_zero:
    print("Substituted equations:", substituted_equations)
# Out:
# Dimension of variety (full basis): 3
# Full Gröbner basis:
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Minimal generating set:
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
# Dimension with minimal set: 3
#
# Verification with parameterization:
# All equations zero: True

# %%
#  This is the case L_1; Check but do not delete

p = [
    2 * t * s + 6 * t * u + 6 * s * u + 18 * u**2,
    1/2 * t * s - 1/2 * t * u - 1/2 * s * u + 1/2 * u**2,
    -1/3 * t**2 * s**2 - 2/3 * t**2 * s * u - 2/3 * t * s**2 * u - t**2 * u**2 + 
    8/3 * t * s * u**2 - s**2 * u**2 + 2 * t * u**3 + 2 * s * u**3 - 3 * u**4,
    -t**3 * s + 2 * t**2 * s**2 - t * s**3 - t**3 * u + t**2 * s * u + 
    t * s**2 * u - s**3 * u + 3 * t**2 * u**2 - 6 * t * s * u**2 + 3 * s**2 * u**2
]

# %%
from sage.all import *

# Define the ring
weights = (5, 4, 3, 3, 2, 2)  # For x5, x4, x3, x2, x1, x0
R = PolynomialRing(QQ, 'u, t,s,x5,x4,x3,x2,x1,x0', order='deglex')
u, t, s, x5, x4, x3, x2, x1, x0 = R.gens()

p = [
    2 * t * s + 6 * t * u + 6 * s * u + 18 * u**2,
    1/Rational(2) * t * s - 1/Rational(2) * t * u - 1/Rational(2) * s * u + 1/Rational(2) * u**2,
    -1/Rational(3) * t**2 * s**2 - 2/Rational(3) * t**2 * s * u - 2/Rational(3) * t * s**2 * u - t**2 * u**2 + 
    8/Rational(3) * t * s * u**2 - s**2 * u**2 + 2 * t * u**3 + 2 * s * u**3 - 3 * u**4,
    -t**3 * s + 2 * t**2 * s**2 - t * s**3 - t**3 * u + t**2 * s * u + 
    t * s**2 * u - s**3 * u + 3 * t**2 * u**2 - 6 * t * s * u**2 + 3 * s**2 * u**2
]

# Define the ideal
eqs = [x0 - p[0], x1 - p[1],   x4 - p[2], x5 - p[3]]
I = R.ideal(eqs)

# Eliminate t and s
I_ts = I.elimination_ideal([u, t, s])

# Print results line-by-line
print("Equations:")
for eq in eqs:
    print(str(eq))

print("\nGröbner basis after eliminating u, t, s:")
for g in I_ts.gens():
    print(str(g))
# Out:
# Equations:
# -18*u^2 - 6*u*t - 6*u*s - 2*t*s + x0
# -1/2*u^2 + 1/2*u*t + 1/2*u*s - 1/2*t*s + x1
# 3*u^4 - 2*u^3*t - 2*u^3*s + u^2*t^2 - 8/3*u^2*t*s + u^2*s^2 + 2/3*u*t^2*s + 2/3*u*t*s^2 + 1/3*t^2*s^2 + x4
# -3*u^2*t^2 + 6*u^2*t*s - 3*u^2*s^2 + u*t^3 - u*t^2*s - u*t*s^2 + u*s^3 + t^3*s - 2*t^2*s^2 + t*s^3 + x5
#
# Gröbner basis after eliminating u, t, s:
# 256*x1^3*x0^3 + 384*x5*x1^2*x0^2 - 432*x5^2*x1^2 - 72*x5^2*x1*x0 - 27*x5^2*x0^2 - 1152*x5*x4*x1*x0 - 6912*x4^2*x1*x0 - 864*x5^2*x4 - 6912*x5*x4^2 - 13824*x4^3

# %%
from sage.all import *

# Define weights: u, t, s (1, 1, 1), x5, x4, x3, x2, x1, x0 (5, 4, 3, 3, 2, 2)
weights = (1, 1, 1, 5, 4, 3, 3, 2, 2)
R = PolynomialRing(QQ, 'u,t,s,x5,x4,x3,x2,x1,x0', order=TermOrder('wdeglex', weights))
u, t, s, x5, x4, x3, x2, x1, x0 = R.gens()

# Define p with exact rational coefficients
p = [
    2 * t * s + 6 * t * u + 6 * s * u + 18 * u**2,
    1/Rational(2) * t * s - 1/Rational(2) * t * u - 1/Rational(2) * s * u + 1/Rational(2) * u**2,
    -1/Rational(3) * t**2 * s**2 - 2/Rational(3) * t**2 * s * u - 2/Rational(3) * t * s**2 * u - t**2 * u**2 + 
    8/Rational(3) * t * s * u**2 - s**2 * u**2 + 2 * t * u**3 + 2 * s * u**3 - 3 * u**4,
    -t**3 * s + 2 * t**2 * s**2 - t * s**3 - t**3 * u + t**2 * s * u + 
    t * s**2 * u - s**3 * u + 3 * t**2 * u**2 - 6 * t * s * u**2 + 3 * s**2 * u**2
]

# Homogenize p[i] to match x_i weights (x0, x1, x4, x5)
p_hom = [
    p[0],                       # degree 2, matches x0: 2
    p[1],                       # degree 2, matches x1: 2
    p[2],                       # degree 4, matches x4: 4
    p[3] * u                    # degree 4+1 = 5, matches x5: 5
]

# Define the ideal (x2 = 0, x3 = 0 explicitly)
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - 0*u**3, x3 - 0*u**3, x4 - p_hom[2], x5 - p_hom[3]]
I = R.ideal(eqs)

# Eliminate u, t, s
I_uts = I.elimination_ideal([u, t, s])

# Print equations one per line
print("Equations:")
for eq in eqs:
    print(eq)

# Print elimination ideal generators one per line
print("\nGröbner basis after eliminating u, t, s:")
for g in I_uts.gens():
    print(g)

# Compute weighted Gröbner basis
R_x = PolynomialRing(QQ, 'x5,x4,x3,x2,x1,x0', order=TermOrder('wdeglex', (5,4,3,3,2,2)))
x5, x4, x3, x2, x1, x0 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_uts.gens()])
G = I_x.groebner_basis()

# Print weighted Gröbner basis one per line
print("\nWeighted Gröbner basis:")
for g in G:
    print(g)

# Check weighted homogeneity
weights_dict = {x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}
print("\nDegrees of each polynomial in the weighted Gröbner basis:")
for g in G:
    degrees = [sum(weights_dict.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees of {g}: {set(degrees)}")
# Out:
# Equations:
# -18*u^2 - 6*u*t - 6*u*s - 2*t*s + x0
# -1/2*u^2 + 1/2*u*t + 1/2*u*s - 1/2*t*s + x1
# x2
# x3
# 3*u^4 - 2*u^3*t - 2*u^3*s + u^2*t^2 - 8/3*u^2*t*s + u^2*s^2 + 2/3*u*t^2*s + 2/3*u*t*s^2 + 1/3*t^2*s^2 + x4
# -3*u^3*t^2 + 6*u^3*t*s - 3*u^3*s^2 + u^2*t^3 - u^2*t^2*s - u^2*t*s^2 + u^2*s^3 + u*t^3*s - 2*u*t^2*s^2 + u*t*s^3 + x5
#
# Gröbner basis after eliminating u, t, s:
# x2
# x3
# 23328*x5^4*x4 + 11664*x5^4*x1^2 + 1944*x5^4*x1*x0 + 729*x5^4*x0^2 + 93312*x5^2*x4^3*x1 + 23328*x5^2*x4^3*x0 + 46656*x5^2*x4^2*x1^2*x0 + 11664*x5^2*x4^2*x1*x0^2 - 1728*x5^2*x1^4*x0^3 - 432*x5^2*x1^3*x0^4 + 186624*x4^6 + 186624*x4^5*x1*x0 + 46656*x4^4*x1^2*x0^2 - 6912*x4^3*x1^3*x0^3 - 3456*x4^2*x1^4*x0^4 + 64*x1^6*x0^6
#
# Weighted Gröbner basis:
# ...

# %%
#   This is L_1

from sage.all import *

# Weights: u, s, t (1, 1, 1), x0, x1, x2, x3, x4, x5 (2, 2, 3, 3, 4, 5)
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogenized p_orig
p_hom = [
    2 * s * t + 6 * s * u + 6 * t * u + 18 * u**2,  # 2(s + 3)(t + 3) homogenized
    1/Rational(2) * s * t - 1/Rational(2) * s * u - 1/Rational(2) * t * u + 1/Rational(2) * u**2,  # (s - 1)(t - 1)/2 homogenized
    0 * u**3,  # 0 for x2
    0 * u**3,  # 0 for x3
    -1/Rational(3) * (s**2 * t**2 + 2 * s**2 * t * u + 3 * s**2 * u**2 + 2 * s * t**2 * u - 8 * s * t * u**2 - 6 * s * u**3 + 3 * t**2 * u**2 - 6 * t * u**3 + 9 * u**4),  # p[4] homogenized
    -u * (s - t)**2 * (s * t + s * u + t * u - 3 * u**2)  # p[5] * u homogenized
]

# Define ideal
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)

# Eliminate u, s, t
I_ust = I.elimination_ideal([u, s, t])

print("Equations:")
for eq in eqs:
    print(eq)

print("\nGröbner basis after eliminating u, t, s:")
for g in I_ust.gens():
    print(g)

# Weighted Gröbner basis
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("\nWeighted Gröbner basis:")
for g in G:
    print(g)

weights_dict = {x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}
print("\nDegrees of each polynomial in the weighted Gröbner basis:")
for g in G:
    degrees = [sum(weights_dict.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees of {g}: {set(degrees)}")
# Out:
# Equations:
# -18*u^2 - 6*u*s - 6*u*t - 2*s*t + x0
# -1/2*u^2 + 1/2*u*s + 1/2*u*t - 1/2*s*t + x1
# x2
# x3
# 3*u^4 - 2*u^3*s - 2*u^3*t + u^2*s^2 - 8/3*u^2*s*t + u^2*t^2 + 2/3*u*s^2*t + 2/3*u*s*t^2 + 1/3*s^2*t^2 + x4
# -3*u^3*s^2 + 6*u^3*s*t - 3*u^3*t^2 + u^2*s^3 - u^2*s^2*t - u^2*s*t^2 + u^2*t^3 + u*s^3*t - 2*u*s^2*t^2 + u*s*t^3 + x5
#
# Gröbner basis after eliminating u, t, s:
# x3
# x2
# 64*x0^6*x1^6 - 3456*x0^4*x1^4*x4^2 - 432*x0^4*x1^3*x5^2 - 1728*x0^3*x1^4*x5^2 - 6912*x0^3*x1^3*x4^3 + 46656*x0^2*x1^2*x4^4 + 11664*x0^2*x1*x4^2*x5^2 + 729*x0^2*x5^4 + 46656*x0*x1^2*x4^2*x5^2 + 186624*x0*x1*x4^5 + 1944*x0*x1*x5^4 + 23328*x0*x4^3*x5^2 + 11664*x1^2*x5^4 + 93312*x1*x4^3*x5^2 + 186624*x4^6 + 23328*x4*x5^4
#
# Weighted Gröbner basis:
# ...

# %%
from sympy import symbols, simplify

def L1(p):
    x0, x1, x2, x3, x4, x5 = symbols('x0 x1 x2 x3 x4 x5')
    g1 = (x0**6 * x1**6 - 54 * x0**4 * x1**4 * x4**2 - 27/4 * x0**4 * x1**3 * x5**2 - 27 * x0**3 * x1**4 * x5**2 - 
          108 * x0**3 * x1**3 * x4**3 + 729 * x0**2 * x1**2 * x4**4 + 729/4 * x0**2 * x1 * x4**2 * x5**2 + 
          729/64 * x0**2 * x5**4 + 729 * x0 * x1**2 * x4**2 * x5**2 + 2916 * x0 * x1 * x4**5 + 
          243/8 * x0 * x1 * x5**4 + 729/2 * x0 * x4**3 * x5**2 + 729/4 * x1**2 * x5**4 + 
          1458 * x1 * x4**3 * x5**2 + 2916 * x4**6 + 729/2 * x4 * x5**4)
    equations = [g1, x2, x3]
    substitutions = {x0: p[0], x1: p[1], x2: p[2], x3: p[3], x4: p[4], x5: p[5]}
    substituted_equations = [simplify(eq.subs(substitutions)) for eq in equations]
    return substituted_equations == [0, 0, 0]

s, t = symbols('s t')
p_orig = [
    2 * (s + 3) * (t + 3),
    (s - 1) * (t - 1) / 2,
    0,
    0,
    -(s**2 * t**2 + 2 * s**2 * t + 3 * s**2 + 2 * s * t**2 - 8 * s * t - 6 * s + 3 * t**2 - 6 * t + 9) / 3,
    -(s - t)**2 * (s * t + s + t - 3)
]

result = L1(p_orig)
print(result)
# Out:
# True

# %%
#   These are tests for L_2

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0, x1, x2, x3, x4, x5 = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis (dimension:", I_x.dimension(), "):")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Recompute dimension explicitly
print("Primary decomposition dimensions:", [p.dimension() for p in I_x.associated_primes()])

# Test affine patch (u = 1)
R_affine = PolynomialRing(QQ, 's,t,x0,x1,x2,x3,x4,x5')
s, t, x0, x1, x2, x3, x4, x5 = R_affine.gens()
p_affine = [p.subs(u=1) for p in p_hom]
eqs_affine = [x0 - p_affine[0], x1 - p_affine[1], x2 - p_affine[2], x3 - p_affine[3], x4 - p_affine[4], x5 - p_affine[5]]
I_affine = R_affine.ideal(eqs_affine)
I_affine_st = I_affine.elimination_ideal([s, t])
print("\nAffine Gröbner basis (u=1):")
for g in I_affine_st.groebner_basis():
    print(g)
print("Affine dimension:", I_affine_st.dimension())
# Out:
# Full Gröbner basis (dimension: 3 ):
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
# Primary decomposition dimensions: [3]
#
# Affine Gröbner basis (u=1):
# x1^3 + 18*x1^2 - 6*x2^2 + 96*x1 + 128
# x1^2*x3 + 12*x1*x3 - 6*x2*x4 + 32*x3
# x1*x3^2 + 4*x3^2 + 4*x0*x4 - 6*x4^2
# x0^2 + 3/4*x3^2 - 3/2*x0*x4
# x0*x1 + 4*x0 - 3*x4
# x0*x2 - 1/2*x1*x3 - 4*x3
# x2*x3 - x1*x4 + 8/3*x0 - 6*x4
# x5
# Affine dimension: 4

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Parameterization
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Ideal and elimination (projective)
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis (dimension:", I_x.dimension(), "):")
for g in G:
    print(g)
    print(f"Degrees: {set([sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()])}")

# Affine patch (u = 1)
R_affine = PolynomialRing(QQ, 's,t,x0,x1,x2,x3,x4,x5')
s, t, x0_ra, x1_ra, x2_ra, x3_ra, x4_ra, x5_ra = R_affine.gens()
p_affine = [p.subs(u=1) for p in p_hom]
eqs_affine = [x0_ra - p_affine[0], x1_ra - p_affine[1], x2_ra - p_affine[2], x3_ra - p_affine[3], x4_ra - p_affine[4], x5_ra - p_affine[5]]
I_affine = R_affine.ideal(eqs_affine)
I_affine_st = I_affine.elimination_ideal([s, t])

print("\nAffine Gröbner basis (u=1):")
G_affine = I_affine_st.groebner_basis()
for g in G_affine:
    print(g)
    degrees = [sum({x0_ra: 2, x1_ra: 2, x2_ra: 3, x3_ra: 3, x4_ra: 4, x5_ra: 5}.get(R_affine.gen(i+2), 0) * exp[i+2] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Affine dimension:", I_affine_st.dimension())

# Minimal projective set (degrees 5, 6, 7, 8)
minimal_set = [G[7], G[6], G[5], G[4]]  # x5, 6, 7, 8
I_min = R_x.ideal(minimal_set)
print("\nMinimal projective set (degrees 5, 6, 7, 8):")
for g in minimal_set:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_min.dimension())

# Verification in R
print("\nVerification with parameterization in original ring:")
# Map minimal_set to R
minimal_set_in_R = [R(str(g)) for g in minimal_set]
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set_in_R]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations))
if not all(eq.is_zero() for eq in substituted_equations):
    print("Substituted equations:", substituted_equations)
# Out:
# Full Gröbner basis (dimension: 3 ):
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Affine Gröbner basis (u=1):
# x1^3 + 18*x1^2 - 6*x2^2 + 96*x1 + 128
# Degrees: {0, 2, 4, 6}
# x1^2*x3 + 12*x1*x3 - 6*x2*x4 + 32*x3
# Degrees: {3, 5, 7}
# x1*x3^2 + 4*x3^2 + 4*x0*x4 - 6*x4^2
# Degrees: {8, 6}
# x0^2 + 3/4*x3^2 - 3/2*x0*x4
# Degrees: {4, 6}
# x0*x1 + 4*x0 - 3*x4
# Degrees: {2, 4}
# x0*x2 - 1/2*x1*x3 - 4*x3
# Degrees: {3, 5}
# x2*x3 - x1*x4 + 8/3*x0 - 6*x4
# Degrees: {2, 4, 6}
# x5
# Degrees: {5}
# ...

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogeneous parameterization
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Ideal and elimination
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis (dimension:", I_x.dimension(), "):")
for g in G:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

# Minimal set (your working set)
minimal_set = [
    x5_rx,
    x0_rx**2 * x1_rx + 3 * x0_rx * x4_rx - 3 * x3_rx**2,
    x0_rx**2 * x2_rx + Rational('1/2') * x0_rx * x1_rx * x3_rx - 3 * x3_rx * x4_rx,
    x0_rx * x1_rx * x4_rx - x0_rx * x2_rx * x3_rx - Rational('1/2') * x1_rx * x3_rx**2 + 3 * x4_rx**2
]
I_min = R_x.ideal(minimal_set)
print("\nMinimal projective set (degrees 5, 6, 7, 8):")
for g in minimal_set:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_min.dimension())

# Verification
print("\nVerification with homogeneous p:")
minimal_set_in_R = [R(str(g)) for g in minimal_set]
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set_in_R]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations))

# Affine check
R_affine = PolynomialRing(QQ, 's,t,x0,x1,x2,x3,x4,x5')
s, t, x0_ra, x1_ra, x2_ra, x3_ra, x4_ra, x5_ra = R_affine.gens()
p_affine = [p.subs(u=1) for p in p_hom]
eqs_affine = [x0_ra - p_affine[0], x1_ra - p_affine[1], x2_ra - p_affine[2], x3_ra - p_affine[3], x4_ra - p_affine[4], x5_ra - p_affine[5]]
I_affine = R_affine.ideal(eqs_affine)
I_affine_st = I_affine.elimination_ideal([s, t])

print("\nAffine Gröbner basis (u=1):")
G_affine = I_affine_st.groebner_basis()
for g in G_affine:
    print(g)
    degrees = [sum({x0_ra: 2, x1_ra: 2, x2_ra: 3, x3_ra: 3, x4_ra: 4, x5_ra: 5}.get(R_affine.gen(i+2), 0) * exp[i+2] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Affine dimension:", I_affine_st.dimension())
# Out:
# Full Gröbner basis (dimension: 3 ):
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Minimal projective set (degrees 5, 6, 7, 8):
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# Dimension: 3
#
# Verification with homogeneous p:
# All equations zero: True
#
# Affine Gröbner basis (u=1):
# x1^3 + 18*x1^2 - 6*x2^2 + 96*x1 + 128
# Degrees: {0, 2, 4, 6}
# ...

# %%
from sage.all import *

# Rings
weights = (1, 1, 1, 2, 2, 3, 3, 4, 5)
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()

# Homogeneous parameterization
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]

# Ideal and elimination (projective)
eqs = [x0 - p_hom[0], x1 - p_hom[1], x2 - p_hom[2], x3 - p_hom[3], x4 - p_hom[4], x5 - p_hom[5]]
I = R.ideal(eqs)
I_ust = I.elimination_ideal([u, s, t])

R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()
I_x = R_x.ideal([R_x(str(g)) for g in I_ust.gens()])
G = I_x.groebner_basis()

print("Full Gröbner basis (dimension:", I_x.dimension(), "):")
for g in G:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")

# Minimal set (your verified set)
minimal_set = [
    x5_rx,
    x0_rx**2 * x1_rx + 3 * x0_rx * x4_rx - 3 * x3_rx**2,
    x0_rx**2 * x2_rx + Rational('1/2') * x0_rx * x1_rx * x3_rx - 3 * x3_rx * x4_rx,
    x0_rx * x1_rx * x4_rx - x0_rx * x2_rx * x3_rx - Rational('1/2') * x1_rx * x3_rx**2 + 3 * x4_rx**2
]
I_min = R_x.ideal(minimal_set)
print("\nMinimal projective set (degrees 5, 6, 7, 8):")
for g in minimal_set:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_min.dimension())

# Verification with p_hom
print("\nVerification with homogeneous p:")
minimal_set_in_R = [R(str(g)) for g in minimal_set]
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set_in_R]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations))

# Affine check with correct minimal set
R_affine = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5')
x0_ra, x1_ra, x2_ra, x3_ra, x4_ra, x5_ra = R_affine.gens()
I_affine_min = R_affine.ideal([R_affine(str(g)) for g in minimal_set])
print("\nAffine ideal with minimal set (u=1 implicit):")
for g in I_affine_min.groebner_basis():
    print(g)
    degrees = [sum({x0_ra: 2, x1_ra: 2, x2_ra: 3, x3_ra: 3, x4_ra: 4, x5_ra: 5}.get(R_affine.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Affine dimension:", I_affine_min.dimension())

# Verify affine p
p_affine = [p.subs(u=1) for p in p_hom]
substitutions_affine = {x0: p_affine[0], x1: p_affine[1], x2: p_affine[2], x3: p_affine[3], x4: p_affine[4], x5: p_affine[5]}
print("\nVerification with affine p (u=1):")
substituted_equations_affine = [R(str(g)).subs(substitutions_affine) for g in minimal_set]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations_affine))
# Out:
# Full Gröbner basis (dimension: 3 ):
# x0*x2^2*x3^3 - 6*x0*x2*x4^3 + 1/2*x1^2*x3^3*x4 + 1/2*x1*x2*x3^4 - 9*x1*x3*x4^3 + 3*x2*x3^2*x4^2
# Degrees: {17}
# x1^3*x3^3 - 18*x1^2*x3*x4^2 + 18*x1*x2*x3^2*x4 - 12*x2^2*x3^3 + 36*x2*x4^3
# Degrees: {15}
# x0*x1*x2*x3^2 - 6*x0*x2*x4^2 + 1/2*x1^2*x3^3 - 9*x1*x3*x4^2 + 6*x2*x3^2*x4
# Degrees: {13}
# x0*x1^2*x3 - 6*x0*x2*x4 - 6*x1*x3*x4 + 6*x2*x3^2
# Degrees: {9}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x5
# Degrees: {5}
#
# Minimal projective set (degrees 5, 6, 7, 8):
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# Dimension: 3
#
# Verification with homogeneous p:
# All equations zero: True
#
# Affine ideal with minimal set (u=1 implicit):
# ...

# %%
from sage.all import *

# Affine ring (no u, since your p is likely u=1)
R_affine = PolynomialRing(QQ, 's,t,x0,x1,x2,x3,x4,x5')
s, t, x0, x1, x2, x3, x4, x5 = R_affine.gens()

# Affine parameterization (u=1)
p_affine = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s + Rational('1/36') * t**3 + t,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 - Rational('8/3') * s * t - Rational('1/9') * t**4 - Rational('4/3') * t**2,
    0
]

# Affine ideal
eqs_affine = [x0 - p_affine[0], x1 - p_affine[1], x2 - p_affine[2], x3 - p_affine[3], x4 - p_affine[4], x5 - p_affine[5]]
I_affine = R_affine.ideal(eqs_affine)
I_affine_st = I_affine.elimination_ideal([s, t])

print("Affine Gröbner basis (u=1):")
G_affine = I_affine_st.groebner_basis()
for g in G_affine:
    print(g)
    degrees = [sum({x0: 2, x1: 2, x2: 3, x3: 3, x4: 4, x5: 5}.get(R_affine.gen(i+2), 0) * exp[i+2] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Affine dimension:", I_affine_st.dimension())

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()

# Your minimal set
minimal_set = [
    x5_rx,
    x0_rx**2 * x1_rx + 3 * x0_rx * x4_rx - 3 * x3_rx**2,
    x0_rx**2 * x2_rx + Rational('1/2') * x0_rx * x1_rx * x3_rx - 3 * x3_rx * x4_rx,
    x0_rx * x1_rx * x4_rx - x0_rx * x2_rx * x3_rx - Rational('1/2') * x1_rx * x3_rx**2 + 3 * x4_rx**2
]
I_min = R_x.ideal(minimal_set)
print("\nMinimal projective set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_min.dimension())

# Verification
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]
print("\nVerification with homogeneous p:")
minimal_set_in_R = [R(str(g)) for g in minimal_set]
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set_in_R]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations))

print("\nVerification with affine p (u=1):")
substitutions_affine = {x0: p_affine[0], x1: p_affine[1], x2: p_affine[2], x3: p_affine[3], x4: p_affine[4], x5: p_affine[5]}
substituted_equations_affine = [R(str(g)).subs(substitutions_affine) for g in minimal_set]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations_affine))
# Out:
# Affine Gröbner basis (u=1):
# x1^3 + 18*x1^2 - 6*x2^2 + 96*x1 + 128
# Degrees: {0, 2, 4, 6}
# x1^2*x3 + 12*x1*x3 - 6*x2*x4 + 32*x3
# Degrees: {3, 5, 7}
# x1*x3^2 + 4*x3^2 + 4*x0*x4 - 6*x4^2
# Degrees: {8, 6}
# x0^2 + 3/4*x3^2 - 3/2*x0*x4
# Degrees: {4, 6}
# x0*x1 + 4*x0 - 3*x4
# Degrees: {2, 4}
# x0*x2 - 1/2*x1*x3 - 4*x3
# Degrees: {3, 5}
# x2*x3 - x1*x4 + 8/3*x0 - 6*x4
# Degrees: {2, 4, 6}
# x5
# Degrees: {5}
# Affine dimension: 4
#
# Minimal projective set:
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# Dimension: 3
#
# Verification with homogeneous p:
# All equations zero: True
#
# Verification with affine p (u=1):
# All equations zero: True

# %%
from sage.all import *

# Projective ring
R_x = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', (2,2,3,3,4,5)))
x0_rx, x1_rx, x2_rx, x3_rx, x4_rx, x5_rx = R_x.gens()

# Your minimal set
minimal_set = [
    x5_rx,
    x0_rx**2 * x1_rx + 3 * x0_rx * x4_rx - 3 * x3_rx**2,
    x0_rx**2 * x2_rx + Rational('1/2') * x0_rx * x1_rx * x3_rx - 3 * x3_rx * x4_rx,
    x0_rx * x1_rx * x4_rx - x0_rx * x2_rx * x3_rx - Rational('1/2') * x1_rx * x3_rx**2 + 3 * x4_rx**2
]
I_min = R_x.ideal(minimal_set)
print("Minimal projective set:")
for g in minimal_set:
    print(g)
    degrees = [sum({x0_rx: 2, x1_rx: 2, x2_rx: 3, x3_rx: 3, x4_rx: 4, x5_rx: 5}.get(R_x.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Dimension:", I_min.dimension())

# Affine ring
R_affine = PolynomialRing(QQ, 'x0,x1,x2,x3,x4,x5')
x0_ra, x1_ra, x2_ra, x3_ra, x4_ra, x5_ra = R_affine.gens()
I_affine_min = R_affine.ideal([R_affine(str(g)) for g in minimal_set])
print("\nAffine ideal with minimal set:")
G_affine = I_affine_min.groebner_basis()
for g in G_affine:
    print(g)
    degrees = [sum({x0_ra: 2, x1_ra: 2, x2_ra: 3, x3_ra: 3, x4_ra: 4, x5_ra: 5}.get(R_affine.gen(i), 0) * exp[i] for i in range(6)) for exp in g.exponents()]
    print(f"Degrees: {set(degrees)}")
print("Affine dimension:", I_affine_min.dimension())

# Verification
R = PolynomialRing(QQ, 'u,s,t,x0,x1,x2,x3,x4,x5', order=TermOrder('wdeglex', weights))
u, s, t, x0, x1, x2, x3, x4, x5 = R.gens()
p_hom = [
    -2 * s**2 - 4 * s * t - 2 * t**2,
    Rational('1/6') * s**2 - Rational('1/3') * s * t + Rational('1/6') * t**2 - 2 * u**2,
    -Rational('1/36') * s**3 + Rational('1/12') * s**2 * t - Rational('1/12') * s * t**2 - s * u**2 + Rational('1/36') * t**3 + t * u**2,
    Rational('2/3') * s**3 + Rational('2/3') * s**2 * t - Rational('2/3') * s * t**2 - Rational('2/3') * t**3,
    -Rational('1/9') * s**4 + Rational('2/9') * s**2 * t**2 - Rational('4/3') * s**2 * u**2 - Rational('8/3') * s * t * u**2 - Rational('1/9') * t**4 - Rational('4/3') * t**2 * u**2,
    0 * u**5
]
p_affine = [p.subs(u=1) for p in p_hom]

print("\nVerification with homogeneous p:")
minimal_set_in_R = [R(str(g)) for g in minimal_set]
substitutions = {x0: p_hom[0], x1: p_hom[1], x2: p_hom[2], x3: p_hom[3], x4: p_hom[4], x5: p_hom[5]}
substituted_equations = [g.subs(substitutions) for g in minimal_set_in_R]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations))

print("\nVerification with affine p (u=1):")
substitutions_affine = {x0: p_affine[0], x1: p_affine[1], x2: p_affine[2], x3: p_affine[3], x4: p_affine[4], x5: p_affine[5]}
substituted_equations_affine = [R(str(g)).subs(substitutions_affine) for g in minimal_set]
print("All equations zero:", all(eq.is_zero() for eq in substituted_equations_affine))
# Out:
# Minimal projective set:
# x5
# Degrees: {5}
# x0^2*x1 + 3*x0*x4 - 3*x3^2
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x1*x4 - x0*x2*x3 - 1/2*x1*x3^2 + 3*x4^2
# Degrees: {8}
# Dimension: 3
#
# Affine ideal with minimal set:
# x1^3*x3^2 - 2*x0*x1^3*x4 - 12*x2^2*x3^2 + 12*x0*x2^2*x4 + 12*x1*x2*x3*x4 - 6*x1^2*x4^2
# Degrees: {12}
# x0*x1^2*x3 + 6*x2*x3^2 - 6*x0*x2*x4 - 6*x1*x3*x4
# Degrees: {9}
# x0^2*x1 - 3*x3^2 + 3*x0*x4
# Degrees: {6}
# x0^2*x2 + 1/2*x0*x1*x3 - 3*x3*x4
# Degrees: {7}
# x0*x2*x3 + 1/2*x1*x3^2 - x0*x1*x4 - 3*x4^2
# Degrees: {8}
# x5
# Degrees: {5}
# Affine dimension: 3
#
# Verification with homogeneous p:
# All equations zero: True
#
# Verification with affine p (u=1):
# All equations zero: True
